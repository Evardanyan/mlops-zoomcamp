# %%
import mlflow
print("MLflow version:", mlflow.__version__)
# Out:
# MLflow version: 2.21.3

# %% [markdown]
# **MLflow version is 2.21.3.**

# %% [markdown]
# **In output folder saved 4 files.**

# %% [markdown]
# **min_samples_split: 2**

# %% [markdown]
# **need to pass "--default-artifact-root"**

# %% [markdown]
# **Tune model hyperparameters  RMSE is 5.355041749098929**

# %% [markdown]
# **test_rmse 5.719078905521884**
